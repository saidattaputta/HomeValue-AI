# %%
import pandas as pd

df = pd.read_csv("/Users/saidattaputta/Desktop/HomeValue-AI/data/processed/train_features.csv")

print(df["SalePrice"].head())
print(df["SalePrice"].describe())
# Out:
# 0    12.247699
# 1    12.109016
# 2    12.317171
# 3    11.849405
# 4    12.429220
# Name: SalePrice, dtype: float64
# count    1458.000000
# mean       12.024015
# std         0.399713
# min        10.460271
# 25%        11.774720
# 50%        12.001512
# 75%        12.273736
# max        13.534474
# Name: SalePrice, dtype: float64

# %%
import joblib

model = joblib.load("/Users/saidattaputta/Desktop/HomeValue-AI/models/best_model.pkl")

print(model)
print(model.intercept_)
# Out:
# Ridge(alpha=20.0, max_iter=10000, random_state=42, solver='svd')
# 11.823145978799523

# %%
import pandas as pd

train = pd.read_csv("/Users/saidattaputta/Desktop/HomeValue-AI/data/processed/train_features.csv")

print("\n===== Training Data (First Row) =====")
print(train.drop(columns=["SalePrice"]).iloc[[0]].T)
# Out:
# ===== Training Data (First Row) =====
#                              0
# Id                           1
# MSSubClass                  60
# MSZoning                    RL
# LotFrontage               65.0
# LotArea                9.04204
# ...                        ...
# TotalPorchArea              61
# TotalRooms                   8
# Qual_LivingArea      52.113833
# GarageCapacityArea        1096
# OverallQual_Squared         49
#
# [89 rows x 1 columns]
